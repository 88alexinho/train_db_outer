# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
connection = sqlite3.connect('simplefolks.sqlite')

# %%
cursor = connection.cursor()

# %%
query_1 = 'SELECT * FROM homes'
cursor.execute(query_1)
result_1 = cursor.fetchall()
for item in result:
    print(item)
# Out:
# ('Austin', 'urban', 145000)
# ('Blair', 'suburbs', 95000)
# ('Carolina', 'suburbs', 220000)
# ('Carolina', 'urban', 190000)
# ('Dani', 'country', 67000)
# ('Donald', 'urban', 450000)
# ('Donald', 'urban', 260000)
# ('Donald', 'urban', 660000)
# ('Eliza', 'urban', 210000)
# ('Farida', 'suburbs', 180000)
# ('Georgina', 'country', 82000)
# ('Hillary', 'country', 380000)
# ('Hillary', 'urban', 400000)
# ('Liam', 'suburbs', 160000)
# ('Leland', 'country', 42000)
# ('Michael', 'suburbs', 160000)
# ('Michael', 'country', 82000)
# ('Phoebe', 'urban', 77000)
# ('Sherry', 'urban', 210000)
# ('Zed', 'country', 177000)

# %%
df_1 = pd.read_sql_query(query_1,connection)

# %%
df_1
# Out:
#    owner_name     area   value
# 0      Austin    urban  145000
# 1       Blair  suburbs   95000
# 2    Carolina  suburbs  220000
# 3    Carolina    urban  190000
# 4        Dani  country   67000
# 5      Donald    urban  450000
# 6      Donald    urban  260000
# 7      Donald    urban  660000
# 8       Eliza    urban  210000
# 9      Farida  suburbs  180000
# 10   Georgina  country   82000
# 11    Hillary  country  380000
# 12    Hillary    urban  400000
# 13       Liam  suburbs  160000
# 14     Leland  country   42000
# 15    Michael  suburbs  160000
# 16    Michael  country   82000
# 17     Phoebe    urban   77000
# 18     Sherry    urban  210000
# 19        Zed  country  177000

# %%
df_1.describe()
# Out:
#                value
# count      20.000000
# mean   212350.000000
# std    154163.028881
# min     42000.000000
# 25%     91750.000000
# 50%    178500.000000
# 75%    230000.000000
# max    660000.000000

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   owner_name  20 non-null     object
#  1   area        20 non-null     object
#  2   value       20 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 612.0+ bytes

# %%
df_1.shape
# Out:
# (20, 3)

# %%
df_1.columns
# Out:
# Index(['owner_name', 'area', 'value'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(12,6))
fig = sns.barplot(x = 'owner_name',y = 'value', data = df_1, color ='aqua', edgecolor = 'black')
# for bar in fig.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    # fig.annotate(format(round((bar.get_height()))), 
    #                (bar.get_x() + bar.get_width() / 2, 
    #                 bar.get_height()), ha='center', va='center',
    #                size=10, xytext=(0, 8),color = 'black',fontweight = 'bold',
    #                textcoords='offset points')
ax.set_facecolor("pink")
plt.grid(which='major', color='grey', linewidth=1,linestyle='--',axis = 'both')
# plt.xlabel('Name',size=15)
# plt.ylabel('Age',size=15)
# plt.title('Personals',fontweight='bold',size=18)
# plt.xticks(df.index,labels = df['owner_name'], rotation =65)
plt.show()

# %%
query_2 = 'SELECT * FROM inmates'
cursor.execute(query_2)
result_2 = cursor.fetchall()
for item in result_2:
    print(item)
# Out:
# ('101', 'JOHN', 'SMITH', 1933, 1978, 1980)
# ('102', 'LOUIS', 'LIBBY', 1945, 1967, 1982)
# ('103', 'HILARY', 'LINTONCAY', 1965, 1985, 1989)
# ('104', 'DAN', 'NOOGEN', 1977, 1995, 1996)
# ('105', 'JANET', 'SMITH', 1954, 1980, 1999)
# ('106', 'ORENTHAL', 'JERRY', 1945, 2009, 2015)
# ('107', 'DONALD', 'DUNK', 1980, 1999, 2004)
# ('108', 'MANNY', 'ROASTANCOWSKI', 1920, 1950, 1955)
# ('109', 'JANET', 'SMITH', 1974, 1998, 2001)

# %%
df_2 = pd.read_sql_query(query_2,connection)

# %%
df_2.head()
# Out:
#     id first_name  last_name  birth_year  sentence_start  sentence_end
# 0  101       JOHN      SMITH        1933            1978          1980
# 1  102      LOUIS      LIBBY        1945            1967          1982
# 2  103     HILARY  LINTONCAY        1965            1985          1989
# 3  104        DAN     NOOGEN        1977            1995          1996
# 4  105      JANET      SMITH        1954            1980          1999

# %%
df_2.shape
# Out:
# (9, 6)

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sns.barplot(x = 'first_name',y = 'birth_year', data = df_2, color ='pink', edgecolor = 'black')
# for bar in fig.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    # fig.annotate(format(round((bar.get_height()))), 
    #                (bar.get_x() + bar.get_width() / 2, 
    #                 bar.get_height()), ha='center', va='center',
    #                size=10, xytext=(0, 8),color = 'black',fontweight = 'bold',
    #                textcoords='offset points')
ax.set_facecolor("b")
plt.grid(which='major', color='grey', linewidth=1,linestyle='--',axis = 'both')
# plt.xlabel('Name',size=15)
# plt.ylabel('Age',size=15)
# plt.title('Personals',fontweight='bold',size=18)
# plt.xticks(df.index,labels = df['owner_name'], rotation =65)
plt.show()

# %%
query_3 = 'SELECT * FROM people'
cursor.execute(query_3)
result_3 = cursor.fetchall()
for item in result_3:
    print(item)
# Out:
# ('Austin', 'M', 33)
# ('Blair', 'M', 90)
# ('Carolina', 'F', 28)
# ('Dani', 'F', 41)
# ('Donald', 'M', 70)
# ('Eliza', 'F', 37)
# ('Farida', 'F', 23)
# ('Georgina', 'F', 19)
# ('Hillary', 'F', 68)
# ('Leland', 'M', 16)
# ('Liam', 'M', 22)
# ('Michael', 'M', 48)
# ('Phoebe', 'F', 52)
# ('Sherry', 'F', 39)
# ('Zed', 'M', 42)

# %%
df_3 = pd.read_sql_query(query_3,connection)
df_3
# Out:
#         name sex  age
# 0     Austin   M   33
# 1      Blair   M   90
# 2   Carolina   F   28
# 3       Dani   F   41
# 4     Donald   M   70
# 5      Eliza   F   37
# 6     Farida   F   23
# 7   Georgina   F   19
# 8    Hillary   F   68
# 9     Leland   M   16
# 10      Liam   M   22
# 11   Michael   M   48
# 12    Phoebe   F   52
# 13    Sherry   F   39
# 14       Zed   M   42

# %%
fig, ax = plt.subplots(figsize=(12,6))
fig = sns.barplot(x = 'name',y = 'age', data = df_3, color ='aqua', edgecolor = 'black')
for bar in fig.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    fig.annotate(format(round((bar.get_height()))), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),color = 'black',fontweight = 'bold',
                   textcoords='offset points')
ax.set_facecolor("pink")
plt.grid(which='major', color='grey', linewidth=1,linestyle='--',axis = 'both')
# plt.xlabel('Name',size=15)
# plt.ylabel('Age',size=15)
# plt.title('Personals',fontweight='bold',size=18)
# plt.xticks(df.index,labels = df['owner_name'], rotation =65)
plt.show()

# %%
df_3[df_3.age>37]['age'].count()
# Out:
# 8

# %%
df_3.groupby(by='sex')['age'].mean()
# Out:
# sex
# F    38.375000
# M    45.857143
# Name: age, dtype: float64
